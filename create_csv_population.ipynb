# %%
import zipfile
import csv
import geopandas as gpd
import pandas as pd
#pd.set_option('display.max_rows', None)

# %%
zip_file_path = '/Users/alina/Documents/geospatial_analysis/mo-shape.zip'
shapefile_name = 'mo.shp'

# extracting shapefile from zip
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall()

moscow_municipal = gpd.read_file(shapefile_name)

# %%
moscow_municipal = moscow_municipal.drop(columns='geometry')

# %%
moscow_municipal['population'] = 0

# %%
moscow_municipal.loc[moscow_municipal['NAME'] == '"Мосрентген"', 'population'] = 22029
moscow_municipal.loc[moscow_municipal['NAME'] == 'Академический', 'population'] = 113198
moscow_municipal.loc[moscow_municipal['NAME'] == 'Алексеевский', 'population'] = 78502
moscow_municipal.loc[moscow_municipal['NAME'] == 'Алтуфьевский', 'population'] = 55753
moscow_municipal.loc[moscow_municipal['NAME'] == 'Арбат', 'population'] = 35962
moscow_municipal.loc[moscow_municipal['NAME'] == 'Аэропорт', 'population'] = 81964
moscow_municipal.loc[moscow_municipal['NAME'] == 'Бабушкинский', 'population'] = 68075
moscow_municipal.loc[moscow_municipal['NAME'] == 'Басманный', 'population'] = 109051
moscow_municipal.loc[moscow_municipal['NAME'] == 'Беговой', 'population'] = 42729
moscow_municipal.loc[moscow_municipal['NAME'] == 'Бескудниковский', 'population'] = 78556
moscow_municipal.loc[moscow_municipal['NAME'] == 'Бибирево', 'population'] = 159344
moscow_municipal.loc[moscow_municipal['NAME'] == 'Бирюлёво Восточное', 'population'] = 157292
moscow_municipal.loc[moscow_municipal['NAME'] == 'Бирюлёво Западное', 'population'] = 86038
moscow_municipal.loc[moscow_municipal['NAME'] == 'Богородское', 'population'] = 108657
moscow_municipal.loc[moscow_municipal['NAME'] == 'Братеево', 'population'] = 102572
moscow_municipal.loc[moscow_municipal['NAME'] == 'Бутырский', 'population'] = 72472
moscow_municipal.loc[moscow_municipal['NAME'] == 'Вешняки', 'population'] = 119927
moscow_municipal.loc[moscow_municipal['NAME'] == 'Внуково', 'population'] = 26182
moscow_municipal.loc[moscow_municipal['NAME'] == 'Внуковское', 'population'] = 63312
moscow_municipal.loc[moscow_municipal['NAME'] == 'Войковский', 'population'] = 72033
moscow_municipal.loc[moscow_municipal['NAME'] == 'Вороновское', 'population'] = 14592
moscow_municipal.loc[moscow_municipal['NAME'] == 'Воскресенское', 'population'] = 20317
moscow_municipal.loc[moscow_municipal['NAME'] == 'Восточное Дегунино', 'population'] = 101601
moscow_municipal.loc[moscow_municipal['NAME'] == 'Восточное Измайлово', 'population'] = 73929
moscow_municipal.loc[moscow_municipal['NAME'] == 'Восточный', 'population'] = 12906
moscow_municipal.loc[moscow_municipal['NAME'] == 'Выхино-Жулебино', 'population'] = 241783
moscow_municipal.loc[moscow_municipal['NAME'] == 'Гагаринский', 'population'] = 80987
moscow_municipal.loc[moscow_municipal['NAME'] == 'Головинский', 'population'] = 104554
moscow_municipal.loc[moscow_municipal['NAME'] == 'Гольяново', 'population'] = 165243
moscow_municipal.loc[moscow_municipal['NAME'] == 'Даниловский', 'population'] = 105140
moscow_municipal.loc[moscow_municipal['NAME'] == 'Десёновское', 'population'] = 45606
moscow_municipal.loc[moscow_municipal['NAME'] == 'Дмитровский', 'population'] = 103271
moscow_municipal.loc[moscow_municipal['NAME'] == 'Донской', 'population'] = 51967
moscow_municipal.loc[moscow_municipal['NAME'] == 'Дорогомилово', 'population'] = 76926
moscow_municipal.loc[moscow_municipal['NAME'] == 'Замоскворечье', 'population'] = 54521
moscow_municipal.loc[moscow_municipal['NAME'] == 'Западное Дегунино', 'population'] = 85514
moscow_municipal.loc[moscow_municipal['NAME'] == 'Зюзино', 'population'] = 124527
moscow_municipal.loc[moscow_municipal['NAME'] == 'Зябликово', 'population'] = 133651
moscow_municipal.loc[moscow_municipal['NAME'] == 'Ивановское', 'population'] = 125042
moscow_municipal.loc[moscow_municipal['NAME'] == 'Измайлово', 'population'] = 107953
moscow_municipal.loc[moscow_municipal['NAME'] == 'Капотня', 'population'] = 32717
moscow_municipal.loc[moscow_municipal['NAME'] == 'Киевский', 'population'] = 12072
moscow_municipal.loc[moscow_municipal['NAME'] == 'Клёновское', 'population'] = 5609
moscow_municipal.loc[moscow_municipal['NAME'] == 'Кокошкино', 'population'] = 21818
moscow_municipal.loc[moscow_municipal['NAME'] == 'Коньково', 'population'] = 151790
moscow_municipal.loc[moscow_municipal['NAME'] == 'Коптево', 'population'] = 102809
moscow_municipal.loc[moscow_municipal['NAME'] == 'Косино-Ухтомский', 'population'] = 89113
moscow_municipal.loc[moscow_municipal['NAME'] == 'Котловка', 'population'] = 64976
moscow_municipal.loc[moscow_municipal['NAME'] == 'Краснопахорское', 'population'] = 12896
moscow_municipal.loc[moscow_municipal['NAME'] == 'Красносельский', 'population'] = 45691
moscow_municipal.loc[moscow_municipal['NAME'] == 'Крылатское', 'population'] = 82923
moscow_municipal.loc[moscow_municipal['NAME'] == 'Крюково', 'population'] = 108426
moscow_municipal.loc[moscow_municipal['NAME'] == 'Кузьминки', 'population'] = 140670
moscow_municipal.loc[moscow_municipal['NAME'] == 'Кунцево', 'population'] = 153316
moscow_municipal.loc[moscow_municipal['NAME'] == 'Куркино', 'population'] = 32326
moscow_municipal.loc[moscow_municipal['NAME'] == 'Левобережный', 'population'] = 55355
moscow_municipal.loc[moscow_municipal['NAME'] == 'Лефортово', 'population'] = 106078
moscow_municipal.loc[moscow_municipal['NAME'] == 'Лианозово', 'population'] = 84811
moscow_municipal.loc[moscow_municipal['NAME'] == 'Ломоносовский', 'population'] = 87923
moscow_municipal.loc[moscow_municipal['NAME'] == 'Лосиноостровский', 'population'] = 82683
moscow_municipal.loc[moscow_municipal['NAME'] == 'Люблино', 'population'] = 181447
moscow_municipal.loc[moscow_municipal['NAME'] == 'Марушкинское', 'population'] = 15692
moscow_municipal.loc[moscow_municipal['NAME'] == 'Марфино', 'population'] = 36566
moscow_municipal.loc[moscow_municipal['NAME'] == 'Марьина Роща', 'population'] = 63095
moscow_municipal.loc[moscow_municipal['NAME'] == 'Марьино', 'population'] = 271915
moscow_municipal.loc[moscow_municipal['NAME'] == 'Матушкино', 'population'] = 41877
moscow_municipal.loc[moscow_municipal['NAME'] == 'Метрогородок', 'population'] = 39623
moscow_municipal.loc[moscow_municipal['NAME'] == 'Мещанский', 'population'] = 56620
moscow_municipal.loc[moscow_municipal['NAME'] == 'Митино', 'population'] = 197840
moscow_municipal.loc[moscow_municipal['NAME'] == 'Михайлово-Ярцевское', 'population'] = 9287
moscow_municipal.loc[moscow_municipal['NAME'] == 'Можайский', 'population'] = 147606
moscow_municipal.loc[moscow_municipal['NAME'] == 'Молжаниновский', 'population'] = 12487
moscow_municipal.loc[moscow_municipal['NAME'] == 'Москворечье-Сабурово', 'population'] = 88095
moscow_municipal.loc[moscow_municipal['NAME'] == 'Московский', 'population'] = 111718
moscow_municipal.loc[moscow_municipal['NAME'] == 'Нагатино-Садовники', 'population'] = 83658
moscow_municipal.loc[moscow_municipal['NAME'] == 'Нагатинский Затон', 'population'] = 120618
moscow_municipal.loc[moscow_municipal['NAME'] == 'Нагорный', 'population'] = 77938
moscow_municipal.loc[moscow_municipal['NAME'] == 'Некрасовка', 'population'] = 108388
moscow_municipal.loc[moscow_municipal['NAME'] == 'Нижегородский', 'population'] = 49563
moscow_municipal.loc[moscow_municipal['NAME'] == 'Ново-Переделкино', 'population'] = 123219
moscow_municipal.loc[moscow_municipal['NAME'] == 'Новогиреево', 'population'] = 99961
moscow_municipal.loc[moscow_municipal['NAME'] == 'Новокосино', 'population'] = 106320
moscow_municipal.loc[moscow_municipal['NAME'] == 'Новофёдоровское', 'population'] = 21725
moscow_municipal.loc[moscow_municipal['NAME'] == 'Обручевский', 'population'] = 87447
moscow_municipal.loc[moscow_municipal['NAME'] == 'Орехово-Борисово Северное', 'population'] = 126387
moscow_municipal.loc[moscow_municipal['NAME'] == 'Орехово-Борисово Южное', 'population'] = 148059
moscow_municipal.loc[moscow_municipal['NAME'] == 'Останкинский', 'population'] = 65296
moscow_municipal.loc[moscow_municipal['NAME'] == 'Отрадное', 'population'] = 187728
moscow_municipal.loc[moscow_municipal['NAME'] == 'Очаково-Матвеевское', 'population'] = 127680
moscow_municipal.loc[moscow_municipal['NAME'] == 'Первомайское', 'population'] = 24782
moscow_municipal.loc[moscow_municipal['NAME'] == 'Перово', 'population'] = 135315
moscow_municipal.loc[moscow_municipal['NAME'] == 'Печатники', 'population'] = 90252
moscow_municipal.loc[moscow_municipal['NAME'] == 'Покровское-Стрешнево', 'population'] = 66564
moscow_municipal.loc[moscow_municipal['NAME'] == 'Преображенское', 'population'] = 87630
moscow_municipal.loc[moscow_municipal['NAME'] == 'Пресненский', 'population'] = 126433
moscow_municipal.loc[moscow_municipal['NAME'] == 'Проспект Вернадского', 'population'] = 65529
moscow_municipal.loc[moscow_municipal['NAME'] == 'Раменки', 'population'] = 152594
moscow_municipal.loc[moscow_municipal['NAME'] == 'Роговское', 'population'] = 6478
moscow_municipal.loc[moscow_municipal['NAME'] == 'Ростокино', 'population'] = 52059
moscow_municipal.loc[moscow_municipal['NAME'] == 'Рязановское', 'population'] = 32215
moscow_municipal.loc[moscow_municipal['NAME'] == 'Рязанский', 'population'] = 107857
moscow_municipal.loc[moscow_municipal['NAME'] == 'Савёлки', 'population'] = 36840
moscow_municipal.loc[moscow_municipal['NAME'] == 'Савёловский', 'population'] = 60070
moscow_municipal.loc[moscow_municipal['NAME'] == 'Свиблово', 'population'] = 60984
moscow_municipal.loc[moscow_municipal['NAME'] == 'Северное Бутово', 'population'] = 97658
moscow_municipal.loc[moscow_municipal['NAME'] == 'Северное Измайлово', 'population'] = 84986
moscow_municipal.loc[moscow_municipal['NAME'] == 'Северное Медведково', 'population'] = 53544
moscow_municipal.loc[moscow_municipal['NAME'] == 'Северное Тушино', 'population'] = 171805
moscow_municipal.loc[moscow_municipal['NAME'] == 'Северный', 'population'] = 130574
moscow_municipal.loc[moscow_municipal['NAME'] == 'Силино', 'population'] = 41586
moscow_municipal.loc[moscow_municipal['NAME'] == 'Сокол', 'population'] = 58000
moscow_municipal.loc[moscow_municipal['NAME'] == 'Соколиная Гора', 'population'] = 93183
moscow_municipal.loc[moscow_municipal['NAME'] == 'Сокольники', 'population'] = 59914
moscow_municipal.loc[moscow_municipal['NAME'] == 'Солнцево', 'population'] = 127304
moscow_municipal.loc[moscow_municipal['NAME'] == 'Сосенское', 'population'] = 115545
moscow_municipal.loc[moscow_municipal['NAME'] == 'Старое Крюково', 'population'] = 33776
moscow_municipal.loc[moscow_municipal['NAME'] == 'Строгино', 'population'] = 161980
moscow_municipal.loc[moscow_municipal['NAME'] == 'Таганский', 'population'] = 135106
moscow_municipal.loc[moscow_municipal['NAME'] == 'Тверской', 'population'] = 75593
moscow_municipal.loc[moscow_municipal['NAME'] == 'Текстильщики', 'population'] = 102752
moscow_municipal.loc[moscow_municipal['NAME'] == 'Тимирязевский', 'population'] = 81940
moscow_municipal.loc[moscow_municipal['NAME'] == 'Троицк', 'population'] = 71089
moscow_municipal.loc[moscow_municipal['NAME'] == 'Тропарёво-Никулино', 'population'] = 128359
moscow_municipal.loc[moscow_municipal['NAME'] == 'Тёплый Стан', 'population'] = 132338
moscow_municipal.loc[moscow_municipal['NAME'] == 'Фили-Давыдково', 'population'] = 112246
moscow_municipal.loc[moscow_municipal['NAME'] == 'Филимонковское', 'population'] = 16237
moscow_municipal.loc[moscow_municipal['NAME'] == 'Филёвский Парк', 'population'] = 113015
moscow_municipal.loc[moscow_municipal['NAME'] == 'Хамовники', 'population'] = 105275
moscow_municipal.loc[moscow_municipal['NAME'] == 'Ховрино', 'population'] = 93029
moscow_municipal.loc[moscow_municipal['NAME'] == 'Хорошёво-Мнёвники', 'population'] = 181520
moscow_municipal.loc[moscow_municipal['NAME'] == 'Хорошёвский', 'population'] = 74927
moscow_municipal.loc[moscow_municipal['NAME'] == 'Царицыно', 'population'] = 120748
moscow_municipal.loc[moscow_municipal['NAME'] == 'Чертаново Северное', 'population'] = 110895
moscow_municipal.loc[moscow_municipal['NAME'] == 'Чертаново Центральное', 'population'] = 113208
moscow_municipal.loc[moscow_municipal['NAME'] == 'Чертаново Южное', 'population'] = 158304
moscow_municipal.loc[moscow_municipal['NAME'] == 'Черёмушки', 'population'] = 107799
moscow_municipal.loc[moscow_municipal['NAME'] == 'Щаповское', 'population'] = 13350
moscow_municipal.loc[moscow_municipal['NAME'] == 'Щербинка', 'population'] = 64132
moscow_municipal.loc[moscow_municipal['NAME'] == 'Щукино', 'population'] = 109248
moscow_municipal.loc[moscow_municipal['NAME'] == 'Южное Бутово', 'population'] = 208783
moscow_municipal.loc[moscow_municipal['NAME'] == 'Южное Медведково', 'population'] = 86996
moscow_municipal.loc[moscow_municipal['NAME'] == 'Южное Тушино', 'population'] = 111492
moscow_municipal.loc[moscow_municipal['NAME'] == 'Южнопортовый', 'population'] = 72414
moscow_municipal.loc[moscow_municipal['NAME'] == 'Якиманка', 'population'] = 27481
moscow_municipal.loc[moscow_municipal['NAME'] == 'Ярославский', 'population'] = 99656
moscow_municipal.loc[moscow_municipal['NAME'] == 'Ясенево', 'population'] = 175253

# %%
moscow_municipal.sort_values(by=['NAME'])
# Out:
#                           NAME     OKATO     OKTMO           NAME_AO  \
# 4                 "Мосрентген"  45297568  45953000    Новомосковский
# 76               Академический  45293554  45397000      Юго-Западный
# 108               Алексеевский  45280552  45349000  Северо-Восточный
# 78                Алтуфьевский  45280554  45350000  Северо-Восточный
# 82                       Арбат  45286552  45374000       Центральный
# 65                    Аэропорт  45277553  45333000          Северный
# 111               Бабушкинский  45280556  45351000  Северо-Восточный
# 104                  Басманный  45286555  45375000       Центральный
# 62                     Беговой  45277556  45334000          Северный
# 68             Бескудниковский  45277559  45335000          Северный
# 91                    Бибирево  45280558  45352000  Северо-Восточный
# 110         Бирюлёво Восточное  45296553  45911000             Южный
# 92           Бирюлёво Западное  45296555  45912000             Южный
# ...

# %%
moscow_municipal.to_csv('moscow_municipal_population_2023.csv', index=False)
